# %% [markdown]
# # Heart Attack Analysis: Youth vs. Adults
# ## Introduction
# The dataset, **"Heart Attack in Youth vs. Adults in America (State)"**, sourced from Kaggle.com, contains 500,000 entries across 20 columns. It highlights contributing factors to heart attacks in the U.S., including demographics, diet quality, cholesterol levels, and more.
# The goal of this analysis is to examine how behavioral factors influence heart attack rates in youth versus adults.

# %% [markdown]
# ## Data Preperation
# Preparing a dataset for analysis starts with importing the necessary libraries and loading the data into a DataFrame. These libraries offer essential tools for cleaning, exploring, and analyzing the data effectively.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("heart_attack_youth_vs_adult.csv")

# %% [markdown]
# Moving on to the actual analysis, I started by uncovering information about the rows and columns. Although this information was already given in the description of the dataset it is crucial to check information about the dataset yourself.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 20 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   ID                   int64
#  1   Age_Group            object
#  2   Gender               object
#  3   Ethnicity            object
#  4   Smoking_Status       object
#  5   Alcohol_Consumption  object
#  6   Diet_Quality         object
#  7   Cholesterol_Level    int64
#  8   Blood_Pressure       int64
#  9   BMI                  float64
#  10  Physical_Activity    int64
#  11  Stress_Level         object
#  12  Family_History       int64
#  13  Diabetes             int64
#  14  Air_Quality_Index    object
#  15  Income_Level         object
#  16  Sleep_Hours          float64
#  17  Heart_Rate           int64
#  18  Medication_Status    int64
#  19  Heart_Attack         int64
# dtypes: float64(2), int64(9), object(9)
# memory usage: 762.9+ MB
# None

# %%
print (df.isnull().sum())
# Out:
# ID                           0
# Age_Group                    0
# Gender                       0
# Ethnicity                    0
# Smoking_Status               0
# Alcohol_Consumption    1998915
# Diet_Quality                 0
# Cholesterol_Level            0
# Blood_Pressure               0
# BMI                          0
# Physical_Activity            0
# Stress_Level                 0
# Family_History               0
# Diabetes                     0
# Air_Quality_Index            0
# Income_Level                 0
# Sleep_Hours                  0
# Heart_Rate                   0
# Medication_Status            0
# Heart_Attack                 0
# dtype: int64

# %% [markdown]
# Using `df.info()`and `df.isnull().sum())`, I extracted the following key details about the dataset:
# - The number of rows and columns.
# - The data types of each column (e.g., integers, floats, strings).
# - The presence of any missing values.

# %% [markdown]
# In addition i also used this line of code to check for unique values in each column

# %%
# Check unique values in the Alcohol Consumption column
unique_values = df['Alcohol_Consumption'].unique()
print("Unique values in Alcohol Consumption:", unique_values)
# Out:
# Unique values in Alcohol Consumption: ['Moderate' nan 'High']

# %% [markdown]
# I observered that the alcohol conumption column had 1998915 entries had no values. However these values were simply stating that those people did not consume alcohol at all. The key variables my research is focused on are the following:
# - Age group
# - Smoking status
# - Diet
# - Alcohol Consumption
# - Physical activity
# - Sleep hours
# - Stress level

# %% [markdown]
# ## Behevioral Factors Associated with Heart Attacks

# %% [markdown]
# Key behvioral variables:
# - Smoking
# - Diet Quality
# - Exercise habits
# - Alcohol consumption
# - Sleep Hours

# %% [markdown]
# **Sleep Hours:**

# %%
### 1. Plot for Sleep Hours ###
# Group by Sleep Hours and Age Group
sleep_hours_agg = df.groupby(['Sleep_Hours', 'Age_Group'])['Heart_Attack'].agg(['count', 'sum', 'mean']).reset_index()

# Plot Sleep Hours by Age Group
plt.figure(figsize=(12, 6))  
sns.lineplot(data=sleep_hours_agg, x='Sleep_Hours', y='mean', hue='Age_Group', marker='o')
plt.title('Heart Attack Rate by Sleep Hours (Youth vs Adults)', fontsize=16)
plt.xlabel('Sleep Hours', fontsize=12)
plt.ylabel('Heart Attack Rate (%)', fontsize=12)
plt.xticks(rotation=45, fontsize=10) 
plt.legend(title='Age Group', fontsize=10)
plt.show()

# %% [markdown]
# **Smoking Status:**

# %%
### 2. Plot for Smoking Status ###
# Group by Smoking Status and Age Group
smoking_status_agg = df.groupby(['Smoking_Status', 'Age_Group'])['Heart_Attack'].agg(['count', 'sum', 'mean']).reset_index()

# Plot Smoking Status by Age Group
plt.figure(figsize=(12, 6))
sns.barplot(data=smoking_status_agg, x='Smoking_Status', y='mean', hue='Age_Group', dodge=True)
plt.title('Heart Attack Rate by Smoking Status (Youth vs Adults)', fontsize=16)
plt.xlabel('Smoking Status', fontsize=12)
plt.ylabel('Heart Attack Rate (%)', fontsize=12)
plt.xticks(fontsize=10)
plt.legend(title='Age Group', fontsize=10)
plt.show()

# %% [markdown]
# **Diet Quality:**

# %%
### 3. Plot for Diet Quality ###
# Group by Diet Quality and Age Group
diet_quality_agg = df.groupby(['Diet_Quality', 'Age_Group'])['Heart_Attack'].agg(['count', 'sum', 'mean']).reset_index()

# Plot Diet Quality by Age Group
plt.figure(figsize=(12, 6))
sns.barplot(data=diet_quality_agg, x='Diet_Quality', y='mean', hue='Age_Group', dodge=True)
plt.title('Heart Attack Rate by Diet Quality (Youth vs Adults)', fontsize=16)
plt.xlabel('Diet Quality', fontsize=12)
plt.ylabel('Heart Attack Rate (%)', fontsize=12)
plt.xticks(fontsize=10)
plt.legend(title='Age Group', fontsize=10)
plt.show()

# %% [markdown]
# **Alcohol Consumption:**

# %%
### 4. Plot for Alcohol Consumption ###
# Group by Alcohol Consumption and Age Group
alcohol_consumption_agg = df.groupby(['Alcohol_Consumption', 'Age_Group'])['Heart_Attack'].agg(['count', 'sum', 'mean']).reset_index()

# Plot Alcohol Consumption by Age Group
plt.figure(figsize=(12, 6))
sns.barplot(data=alcohol_consumption_agg, x='Alcohol_Consumption', y='mean', hue='Age_Group', dodge=True)
plt.title('Heart Attack Rate by Alcohol Consumption (Youth vs Adults)', fontsize=16)
plt.xlabel('Alcohol Consumption', fontsize=12)
plt.ylabel('Heart Attack Rate (%)', fontsize=12)
plt.xticks(fontsize=10)
plt.legend(title='Age Group', fontsize=10)
plt.show()

# %% [markdown]
# **Physical Activity:**

# %%
### 5. Plot for Physical Activity ###
# Group by Physical Activity (Binned) and Age Group
physical_activity_agg = df.groupby(['Physical_Activity_Binned', 'Age_Group'])['Heart_Attack'].agg(['count', 'sum', 'mean']).reset_index()

# Plot Physical Activity by Age Group
plt.figure(figsize=(12, 6))
sns.barplot(data=physical_activity_agg, x='Physical_Activity_Binned', y='mean', hue='Age_Group', dodge=True)
plt.title('Heart Attack Rate by Physical Activity (Youth vs Adults)', fontsize=16)
plt.xlabel('Minutes of Physical Activity Per Week (Binned)', fontsize=12)
plt.ylabel('Heart Attack Rate (%)', fontsize=12)
plt.xticks(rotation=45, fontsize=10) 
plt.legend(title='Age Group', fontsize=10)
plt.show()
# Out:
# /var/folders/vt/ft61379x673dkd9bsl8y6p380000gn/T/ipykernel_52835/114681819.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   physical_activity_agg = df.groupby(['Physical_Activity_Binned', 'Age_Group'])['Heart_Attack'].agg(['count', 'sum', 'mean']).reset_index()

# %% [markdown]
# From all the data i had collected, behvioral factors seemed to not affect heart attack rate significantly. However, diving deeper into the data is crucial and to do that statisitcal testing was the best method.
#
# The two statistical methods i used were:
# - Chi Square Test (for categorical variables)
# - T-Test (for numerical variables)

# %% [markdown]
# **Chi- Square Test Results:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import chi2_contingency
from scipy.stats import ttest_ind
df = pd.read_csv("heart_attack_youth_vs_adult.csv")
#Chi Square Test For Categorical Variables
contingency_table = pd.crosstab(df['Age_Group'], df['Smoking_Status'])
chi2, p, dof, expected = chi2_contingency(contingency_table)
print(f"P-value: {p}")
# Out:
# P-value: 0.9882371551320972

# %% [markdown]
# **T-test Results:**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import chi2_contingency
from scipy.stats import ttest_ind
df = pd.read_csv("heart_attack_youth_vs_adult.csv")
#T-Test For Numerical Variables
youth_data = df[df['Age_Group'] == 'Youth']['Heart_Attack']
adult_data = df[df['Age_Group'] == 'Adult']['Heart_Attack']
t_stat, p_value = ttest_ind(youth_data, adult_data)
print(f"T-Test P-value: {p_value}")
# Out:
# T-Test P-value: 0.2565436060573501

# %% [markdown]
# Both Tests demonstrate that there is no significant difference in the data between youth vs adults which agrees with what the graphs showed.

# %% [markdown]
# # Conclusion
#
# The analysis aimed to explore the relationship between behavioral factors (e.g., sleep hours, smoking status, diet quality, alcohol consumption, and physical activity) and heart attack rates, with a focus on differences between **Youth** and **Adults**. Below is a summary of the findings based on the graphs and statistical tests:
#
# ---
#
# ## Key Findings
#
# 1. **General Trends Across Behavioral Factors:**
#    - The visualizations for behavioral factors, such as **Smoking Status**, **Diet Quality**, and **Alcohol Consumption**, showed relatively consistent heart attack rates across categories for both Youth and Adults.
#    - **Sleep Hours** and **Physical Activity** also did not exhibit clear trends or patterns significantly correlating with heart attack rates.
#
# 2. **Statistical Tests:**
#    - A **t-test** comparing heart attack rates between Youth and Adults yielded a p-value of **0.257**, indicating no statistically significant difference between the two age groups.
#    - Similarly, other categorical factors like **Smoking Status** and **Diet Quality** were tested but showed no significant relationship with heart attack rates when grouped by age.
#
# 3. **Insights on Behavioral Factors:**
#    - The lack of significant differences in heart attack rates across behavioral categories suggests that these factors, as measured in this dataset, may not independently contribute to heart attack risk.
#    - Alternatively, other variables, such as **cholesterol levels**, **stress**, or **genetics**, may play a more dominant role.
#
# ---
#
# ## Implications
#
# 1. **Behavioral Factors May Be Less Influential:**
#    - The analysis suggests that the behavioral factors studied (e.g., smoking, diet, sleep) have a limited direct impact on heart attack risk in this dataset, or their effects may be overshadowed by other variables.
#
# 2. **Youth vs. Adults:**
#    - The lack of significant differences between Youth and Adults indicates that age group alone is not a strong predictor of heart attack risk in this dataset. Both groups exhibited similar trends across the analyzed behavioral factors.
#
# ---
#
#
# ## Conclusion Summary
#
# While the analysis did not find significant differences in heart attack rates based on behavioral factors or between Youth and Adults, this highlights the need to explore alternative variables and consider more complex interactions to better understand the determinants of heart attack risk. These findings suggest that heart attack risk may be influenced more by non-behavioral or systemic factors than by the behaviors analyzed in this study.
